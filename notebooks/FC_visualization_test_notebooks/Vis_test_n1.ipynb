# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading dataset h5 using Pandas

df = pd.read_hdf('df_individual_analyzed_merged.h5', key='dataframe')

# %%
# printing dataframe

df
# Out:
#                                                                                                                                                                 val
# cond                                  mouse   day   within_factor target            signal_type task_type trial time                      rel_time
# cond_B6-lodger-10min-habituation      AM22043 day11 wICR          roi_target        Continuous            0     2022-09-28 06:47:00+09:00 0 days 00:00:00  0.000000
#                                                                   event_roi_target  Continuous            0     2022-09-28 06:47:00+09:00 0 days 00:00:00  0.000000
#                                                                   roi_control       Continuous            0     2022-09-28 06:47:00+09:00 0 days 00:00:00  0.000000
#                                                                   event_roi_control Continuous            0     2022-09-28 06:47:00+09:00 0 days 00:00:00  0.000000
# ...

# %%
# printing dataframe

df.reset_index()
# Out:
#                                         cond    mouse    day within_factor  \
# 0           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 1           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 2           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 3           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 4           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# ...                                      ...      ...    ...           ...
# 98481  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98482  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98483  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98484  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98485  cond_single-housing-10min-habituation  AM22062   day0         woICR
#
#                   target signal_type task_type  trial  \
# ...

# %%
data = pd.DataFrame(df)

# %%
data.to_csv('data.csv')

# %%
data_frame = pd.read_csv('data.csv')

# %%
data_frame
# Out:
#                                         cond    mouse    day within_factor  \
# 0           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 1           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 2           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 3           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 4           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# ...                                      ...      ...    ...           ...
# 98481  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98482  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98483  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98484  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98485  cond_single-housing-10min-habituation  AM22062   day0         woICR
#
#                   target signal_type  task_type  trial  \
# ...

# %%
data_frame.dtypes
# Out:
# cond              object
# mouse             object
# day               object
# within_factor     object
# target            object
# signal_type       object
# task_type        float64
# trial              int64
# time              object
# rel_time          object
# val              float64
# dtype: object

# %%
target_1 = data_frame[data_frame['target'].isin(['roi_target', 'roi_control'])]

# %%
target_1
# Out:
#                                         cond    mouse    day within_factor  \
# 0           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 2           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 4           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 6           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 8           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# ...                                      ...      ...    ...           ...
# 98476  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98478  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98480  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98482  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98484  cond_single-housing-10min-habituation  AM22062   day0         woICR
#
# ...

# %%
grouped = df.groupby(['mouse', 'target']).mean()

# %%
filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]
grouped = filtered.groupby('mouse').mean()

# %%
filtered
# Out:
#                                         cond    mouse    day within_factor  \
# 0           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 2           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 4           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 6           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 8           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# ...                                      ...      ...    ...           ...
# 98476  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98478  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98480  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98482  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98484  cond_single-housing-10min-habituation  AM22062   day0         woICR
#
# ...

# %%
info_check = filtered[filtered['cond'] == 'cond_B6-lodger-10min-habituation']

# %%
info_check['mouse'].unique()
# Out:
# array(['AM22043', 'AM22044', 'AM22045', 'AM22046'], dtype=object)

# %%
filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]
grouped = filtered.groupby('mouse').mean()

# %%
plt.figure(figsize=(40, 15))
ax = sns.catplot(x='mouse', y='val', hue='target', data=filtered, kind='bar', ci=None, height=8, aspect=1.5)
ax.fig.suptitle('Bar plot of target values for each mouse')
ax.set_xticklabels(rotation=90)
plt.show()

# %%
filtered
# Out:
#                                         cond    mouse    day within_factor  \
# 0           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 2           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 4           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 6           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# 8           cond_B6-lodger-10min-habituation  AM22043  day11          wICR
# ...                                      ...      ...    ...           ...
# 98476  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98478  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98480  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98482  cond_single-housing-10min-habituation  AM22062   day0         woICR
# 98484  cond_single-housing-10min-habituation  AM22062   day0         woICR
#
# ...

# %%
unique_mouse = filtered['mouse'].unique()

# %%
filtered['day'].unique()
# Out:
# array(['day11', 'day0'], dtype=object)

# %%
unique_mouse
# Out:
# array(['AM22043', 'AM22044', 'AM22045', 'AM22046', 'AM22055', 'AM22056',
#        'AM22057', 'AM22058', 'MT290', 'MT291', 'MT292', 'MT293',
#        'AM22025', 'AM22027', 'AM22029', 'AM22039', 'AM22040', 'AM22041',
#        'AM22042', 'AM22028', 'AM22021', 'AM22022_died', 'AM22026',
#        'AM22047', 'AM22048', 'AM22050', 'AM22053', 'AM22049', 'AM22054',
#        'AM22030', 'AM22031', 'AM22032', 'AM22034', 'AM22052', 'AM22033',
#        'AM22035', 'AM22036', 'AM22037', 'AM22038', 'OH323', 'OH325',
#        'OH327', 'OH329', 'AM22023', 'AM22024', 'AM22059', 'AM22060',
#        'AM22061', 'AM22062'], dtype=object)

# %%
# # Filter data by target column
# filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]

# # Create two subplots for categories wICR and woICR
# fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

# # Plot for category wICR
# sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
# axes[0].set_title('Bar plot of target values for each mouse (wICR)')
# axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

# # Plot for category woICR
# sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
# axes[1].set_title('Bar plot of target values for each mouse (woICR)')
# axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

# # Show plots
# plt.show()

# %% [markdown]
# # Final result

# %%
# Filter data by target column
filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]

# Create two subplots for categories wICR and woICR
fig, axes = plt.subplots(2, 1, figsize=(22, 20), sharey=True)

# Plot for category wICR
sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
axes[0].set_title('Bar plot of target values for each mouse (wICR)')
axes[0].set_xlabel('Mouse')
axes[0].set_ylabel('Values')
axes[0].set_ylim([0, 1])
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

# Plot for category woICR
sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
axes[1].set_title('Bar plot of target values for each mouse (woICR)')
axes[0].set_xlabel('Mouse')
axes[0].set_ylabel('Values')
axes[1].set_ylim([0, 1])
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

# Adjust subplot margins
fig.subplots_adjust(hspace=0.7)

# Show plots
plt.show()

# %%
# Define the serotype dataframe
serotype_df = filtered.groupby(['cond', 'target', 'mouse', 'val']).size().unstack().fillna(0)

# %%
data_frame['day']
# Out:
# 0        day11
# 1        day11
# 2        day11
# 3        day11
# 4        day11
#          ...
# 98481     day0
# 98482     day0
# 98483     day0
# 98484     day0
# 98485     day0
# Name: day, Length: 98486, dtype: object

# %%
serotype_df.dtypes
# Out:
# val
# 0.00000    float64
# 0.05000    float64
# 0.05264    float64
# 0.08700    float64
# 0.10000    float64
#             ...
# 0.90000    float64
# 0.93750    float64
# 0.94730    float64
# 0.95000    float64
# 1.00000    float64
# Length: 64, dtype: object

# %%
serotype_df.columns
# Out:
# Float64Index([    0.0,    0.05, 0.05264,   0.087,     0.1,  0.1053,  0.1428,
#                  0.15,  0.1578,  0.1765,  0.1904,     0.2,  0.2106,  0.2142,
#                0.2354,    0.25,  0.2632,  0.2727,     0.3,  0.3157,    0.35,
#                 0.353,  0.3684,  0.3809,     0.4,  0.4211,  0.4285,    0.45,
#                0.4546,  0.4736,   0.476,     0.5,   0.522,   0.524,  0.5264,
#                  0.55,   0.579,     0.6,   0.609,  0.6113,  0.6313,   0.647,
#                  0.65,  0.6665,   0.684,   0.696,     0.7,   0.706,   0.737,
#                  0.75,  0.7896,     0.8,  0.8096,  0.8237,  0.8335,  0.8423,
#                  0.85,  0.8823,  0.8945,     0.9,  0.9375,  0.9473,    0.95,
#                   1.0],
#              dtype='float64', name='val')

# %% [markdown]
# # Creating PDF

# %%
# import matplotlib.backends.backend_pdf as pdf

# # Filter data by target column
# filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]

# # Create a pdf file object
# with pdf.PdfPages("Bar_Plot_for_each_target.pdf") as pdf_file:

#     # Create two subplots for categories wICR and woICR
#     fig, axes = plt.subplots(2, 1, figsize=(22, 20), sharey=True)

#     # Plot for category wICR
#     sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
#     axes[0].set_title('Bar plot of target values for each mouse (wICR)')
#     axes[0].set_xlabel('Mouse')
#     axes[0].set_ylabel('Values')
#     axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

#     # Plot for category woICR
#     sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
#     axes[1].set_title('Bar plot of target values for each mouse (woICR)')
#     axes[0].set_xlabel('Mouse')
#     axes[0].set_ylabel('Values')
#     axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

#     # Adjust subplot margins
#     fig.subplots_adjust(hspace=0.7)

#     # Save the plot to the pdf file
#     pdf_file.savefig(fig)

# %%
filtered['mouse'].unique()

# %%
data_frame

# %%
data_frame['cond'].value_counts()

# %%
data_frame['cond'].unique()

# %% [markdown]
# # Greating Plots by Cond column

# %%
# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Loop through each group
for group in groups:
    # Filter data by target column and group
    filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group)]

    # Create two subplots for categories wICR and woICR
    fig, axes = plt.subplots(1, 2, figsize=(22, 15), sharey=True)

    # Plot for category wICR
    sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
    axes[0].set_title(f'(wICR) - {group}')
    axes[0].set_xlabel('Mouse')
    axes[0].set_ylabel('Values')
    axes[0].set_ylim([0, 1])
    axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

    # Plot for category woICR
    sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
    axes[1].set_title(f'(woICR) - {group}')
    axes[1].set_xlabel('Mouse')
    axes[1].set_ylim([0, 1])
    axes[1].set_ylabel('Values')
    axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

    # Adjust subplot margins
    fig.subplots_adjust(hspace=0.3)

    # Show plots
    plt.show()

# %% [markdown]
# # Checking code

# %%
data_frame['day'].replace('day01', 'day0', inplace=True)

# %%
days = data_frame['day'].unique()
print(days)

# %%
data_frame[data_frame['day'] == 'day0']

# %%
import os
from matplotlib.backends.backend_pdf import PdfPages

# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Create PDF file to save plots
with PdfPages('plots_per_group22222.pdf') as pdf:
    # Loop through each group
    for group in groups:
        # Get unique values in the column day for the current group
        days = data_frame.loc[data_frame['cond'] == group, 'day'].unique()

        for i, day in enumerate(days):
            try:
                # Create two subplots for categories wICR and woICR
                fig, axes = plt.subplots(1, 2, figsize=(7, 7), sharey=True)
                # Filter data by target column, group, and day
                filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group) & (data_frame['day'] == day)]

                # Plot for category wICR
                sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
                axes[0].set_title(f'(wICR) - {group} - {day}')
                axes[0].set_xlabel('Mouse')
                axes[0].set_ylabel('Values')
                axes[0].set_ylim([0, 1])
                axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

                # Plot for category woICR
                sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
                axes[1].set_title(f'(woICR) - {group} - {day}')
                axes[1].set_xlabel('Mouse')
                axes[1].set_ylim([0, 1])
                axes[1].set_ylabel('Values')
                axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

                # Adjust subplot margins
                fig.subplots_adjust(hspace=0.3, right=1.8)

                # Save plot to PDF
                pdf.savefig(fig, bbox_inches='tight',
                            pad_inches=0.5, orientation='portrait')

                # Close the plot to free up memory
                plt.close(fig)

            except ValueError:
                print(f"No data available for group {group}, day {day}. Please check unique values in day column and ammend accordingly")

# %%
# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Loop through each group
for group in groups:
    # Get unique values in the column day for the current group
    days = data_frame.loc[data_frame['cond'] == group, 'day'].unique()

    for i, day in enumerate(days):
        # Create two subplots for categories wICR and woICR
        fig, axes = plt.subplots(1, 2, figsize=(7, 7), sharey=True)
        # Filter data by target column, group, and day
        filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group) & (data_frame['day'] == day)]

        # Plot for category wICR
        sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
        axes[0].set_title(f'(wICR) - {group} - Day {day}')
        axes[0].set_xlabel('Mouse')
        axes[0].set_ylabel('Values')
        axes[0].set_ylim([0, 1])
        axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

        # Plot for category woICR
        sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
        axes[1].set_title(f'(woICR) - {group} - Day {day}')
        axes[1].set_xlabel('Mouse')
        axes[1].set_ylim([0, 1])
        axes[1].set_ylabel('Values')
        axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

        # Adjust subplot margins
        fig.subplots_adjust(hspace=0.3, right=1.8)

        # Show plots
        plt.show()

# %%
groups

# %% [markdown]
# # Final Code!!!!

# %%
# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Loop through each group
for group in groups:
    # Get unique values in the column day for the current group
    days = data_frame.loc[data_frame['cond'] == group, 'day'].unique()

    for i, day in enumerate(days):
        try:
            # Create two subplots for categories wICR and woICR
            fig, axes = plt.subplots(1, 2, figsize=(7, 7), sharey=True)
            # Filter data by target column, group, and day
            filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group) & (data_frame['day'] == day)]

            # Plot for category wICR
            sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[0])
            axes[0].set_title(f'(wICR) - {group} - {day}')
            axes[0].set_xlabel('Mouse')
            axes[0].set_ylabel('Values')
            axes[0].set_ylim([0, 1])
            axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

            # Plot for category woICR
            sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[1])
            axes[1].set_title(f'(woICR) - {group} - {day}')
            axes[1].set_xlabel('Mouse')
            axes[1].set_ylim([0, 1])
            axes[1].set_ylabel('Values')
            axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

            # Adjust subplot margins
            fig.subplots_adjust(hspace=0.3, right=1.8)

            # Show plots
            plt.show()
        except ValueError:
            print(f"No data available for group {group}, day {day}. Please check unique values in day column and ammend accordingly")

# %%
# # Filter data by target column
# filtered = data_frame[data_frame['target'].isin(['roi_control', 'roi_target'])]

# # Create two subplots for categories wICR and woICR
# g = sns.catplot(x='mouse', y='val', hue='target', col='within_factor', data=filtered,
#                 kind='bar', col_wrap=2, height=8, aspect=1.2)

# # Set plot titles
# for ax in g.axes.flat:
#     if ax.title.get_text() == 'wICR':
#         ax.set_title('Bar plot of target values for each mouse (with ICR)')
#     elif ax.title.get_text() == 'woICR':
#         ax.set_title('Bar plot of target values for each mouse (without ICR)')
    
#     # Set x-axis labels
#     ax.set_xlabel('Mouse')
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# # Show plot
# plt.show()

# Get unique values in the column cond
groups = sorted(data_frame['cond'].unique())

# Loop through each group
for group in groups:
    # Filter data by target column, group, and day
    filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group)]

    # Create two subplots for categories wICR and woICR
    fig, axes = plt.subplots(1, 2, figsize=(7, 6), sharey=True)

    # Loop through each day in the filtered data
    for i, day in enumerate(filtered['day'].unique()):
        # Get data for the current day
        day_data = filtered[filtered['day'] == day]

        # Plot for category wICR
        sns.barplot(x='mouse', y='val', hue='target', data=day_data[day_data['within_factor'] == 'wICR'], ci=None, ax=axes[0])
        axes[0].set_title(f'(wICR) - {group} - Day {day}')
        axes[0].set_xlabel('Mouse')
        axes[0].set_ylabel('Values')
        axes[0].set_ylim([0, 1])
        axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

        # Plot for category woICR
        sns.barplot(x='mouse', y='val', hue='target', data=day_data[day_data['within_factor'] == 'woICR'], ci=None, ax=axes[1])
        axes[1].set_title(f'(woICR) - {group} - Day {day}')
        axes[1].set_xlabel('Mouse')
        axes[1].set_ylim([0, 1])
        axes[1].set_ylabel('Values')
        axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

        # Adjust subplot margins
        fig.subplots_adjust(hspace=0.3, right = 1.8)

        # Show plots
        plt.show()

# %%
# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Define number of rows and columns for the subplot grid
n_rows = 2
n_cols = 4

# Create the larger figure with multiple subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 10), sharey=True)

# Loop through each group and day and fill in each subplot with a barplot
for i, group in enumerate(groups):
    # Get unique values in the column day for the current group
    days = data_frame.loc[data_frame['cond'] == group, 'day'].unique()
    for j, day in enumerate(days):
        # Filter data by target column, group, and day
        filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group) & (data_frame['day'] == day)]
        # Get the current subplot
        ax = axes[i//n_cols, i%n_cols*n_rows+j]
        # Plot the barplot on the current subplot
        sns.barplot(x='mouse', y='val', hue='target', data=filtered, ci=None, ax=ax)
        ax.set_title(f'{group} - {day}')
        ax.set_xlabel('Mouse')
        ax.set_ylabel('Values')
        ax.set_ylim([0, 1])
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# Adjust subplot margins
fig.subplots_adjust(hspace=0.3, wspace=0.2)

# Show the plot
plt.show()

# %% [markdown]
# # Possible solution and plot

# %%
# Get unique values in the column cond
groups = data_frame['cond'].unique()

# Create figure with multiple axes
fig, axes = plt.subplots(len(groups), 2, figsize=(4, 80), sharey=True)


# Loop through each group and plot on corresponding axes
for i, group in enumerate(groups):
    # Filter data by target column and group
    filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group)]

    # Plot for category wICR
    # sns.catplot(x='mouse', y='val', hue='target', col='cond', data=filtered[filtered['within_factor'] == 'wICR'], kind='bar', ci=None, sharey=True, height=10, aspect=0.8, col_wrap = 8, margin_titles=True)
    sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'wICR'], ci=None, ax=axes[i, 0])
    axes[i, 0].set_title(f'wICR - {group}', loc = 'left', fontdict={'fontsize': 11})
    # axes[i, 0].set_xlabel('Mouse')
    axes[i, 0].set_ylabel('Values')
    axes[i, 0].set_ylim([0, 1])
    axes[i, 0].set_xticklabels(axes[i, 0].get_xticklabels(), rotation=90)

    # Plot for category woICR
    # sns.catplot(x='mouse', y='val', hue='target', col='cond', data=filtered[filtered['within_factor'] == 'woICR'], kind='bar', ci=None, sharey=True, height=10, aspect=0.8, col_wrap = 8, margin_titles=True)
    sns.barplot(x='mouse', y='val', hue='target', data=filtered[filtered['within_factor'] == 'woICR'], ci=None, ax=axes[i, 1])
    axes[i, 1].set_title(f'woICR - {group}', loc = 'left', fontdict={'fontsize': 11})
    # axes[i, 1].set_xlabel('Mouse')
    axes[i, 1].set_ylim([0, 1])
    axes[i, 1].set_ylabel('Values')
    axes[i, 1].set_xticklabels(axes[i, 1].get_xticklabels(), rotation=90)

    # Adjust subplot margins
fig.subplots_adjust(hspace=0.7, right = 1.8)

# Show plot
plt.show()

# %%
groups = data_frame['cond'].unique()
# Loop through each group and plot on corresponding axes
for i, group in enumerate(groups):
    # Filter data by target column and group
    filtered = data_frame[(data_frame['target'].isin(['roi_control', 'roi_target'])) & (data_frame['cond'] == group)]

    # Loop through each day and plot on corresponding sub-axes
    for j, day in enumerate(filtered['day'].unique()):
        day_filtered = filtered[filtered['day'] == day]

        # Plot for category wICR
        sns.barplot(x='mouse', y='val', hue='target', data=day_filtered[day_filtered['within_factor'] == 'wICR'], ci=None, ax=axes[i, j*2])
        axes[i, j*2].set_title(f'wICR - {group} - {day}', loc='left', fontdict={'fontsize': 11})
        axes[i, j*2].set_ylabel('Values')
        axes[i, j*2].set_ylim([0, 1])
        axes[i, j*2].set_xticklabels(axes[i, j*2].get_xticklabels(), rotation=90)

        # Plot for category woICR
        sns.barplot(x='mouse', y='val', hue='target', data=day_filtered[day_filtered['within_factor'] == 'woICR'], ci=None, ax=axes[i, j*2+1])
        axes[i, j*2+1].set_title(f'woICR - {group} - {day}', loc='left', fontdict={'fontsize': 11})
        axes[i, j*2+1].set_ylabel('Values')
        axes[i, j*2+1].set_ylim([0, 1])
        axes[i, j*2+1].set_xticklabels(axes[i, j*2+1].get_xticklabels(), rotation=90)
        
        # Adjust subplot margins
fig.subplots_adjust(hspace=0.7, right = 1.8)

# Show plot
plt.show()

# %%
# from matplotlib.backends.backend_pdf import PdfPages
# import os

# base_path = r"Z:\project_pfc_n_depression_behavior\SIT2022\1C-SIT"
# df = pd.read_hdf(os.path.join(
#     base_path, 'df_individual_analyzed_merged.h5'), key='dataframe')
# print("File loaded")

# Group data by cond and day
groups = sorted(data_frame.groupby(['cond', 'day']))

# Sort groups by cond
# groups = sorted(groups, key=lambda x: x[0][0])

# Create figure with multiple axes
fig, axes = plt.subplots(len(groups), 2, figsize=(4, 100), sharey=True)

# Loop through each group and plot on corresponding axes
for i, ((cond, day), filtered) in enumerate(groups):
    # Filter data by target column and group
    filtered = filtered[(filtered['target'].isin(['roi_control', 'roi_target']))]

    # Plot for category wICR and woICR
    sns.barplot(x='mouse', y='val', hue='target', data=filtered, ci=None, ax=axes[i, 0])
    sns.barplot(x='mouse', y='val', hue='target', data=filtered, ci=None, ax=axes[i, 1])

    # Set titles for the two bar plots
    for j, category in enumerate(['wICR', 'woICR']):
        axes[i, j].set_title(f'{category} - {cond} - {day}', loc='left', fontdict={'fontsize': 11})
        axes[i, j].set_ylabel('Values')
        axes[i, j].set_ylim([0, 1])
        axes[i, j].tick_params(axis='x', rotation=90)

# Adjust subplot margins
fig.subplots_adjust(hspace=0.7, right=2.3)

# with PdfPages(os.path.join(base_path, 'plots_per_groupv_2.pdf')) as pdf:
#     pdf.savefig(fig, bbox_inches='tight',
#                 pad_inches=0.5, orientation='portrait')

# Show plot
plt.show()
